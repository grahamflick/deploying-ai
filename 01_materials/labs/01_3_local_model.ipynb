# %% [markdown]
# # LM Studio
#
#  LM Studio is a powerful platform designed for working with large language models (LLMs) on your local machine. It provides an intuitive interface for downloading, managing, and running a wide variety of open-source LLMs.
#
# A few characteristics of LM Studio are:
#
# + With LM Studio, users can experiment with different models, customize their settings, and interact with them in real time.
# + The platform supports both CPU and GPU acceleration, making it accessible for a range of hardware configurations.
# + LM Studio is ideal for developers, researchers, and enthusiasts who want to explore LLM capabilities without relying on cloud-based solutions.
#
# You can download and install LMStudio from [lmstudio.ai](https://lmstudio.ai/).
#
# ## LM Studio API
#
# An important characteristic in LM Studio is its support for OpenAI's API:
#
# + LM Studio accepts requests on several OpenAI endpoints and returns OpenAI-like response objects ([lmstudio.ai](https://platform.openai.com/docs/guides/prompt-engineering#message-roles-and-instruction-following)).
# + This means that we can reuse our code by pointing the local API using the `base_url` parameter.

# %% [markdown]
# ## Setup LM Studio
#
# + Download and install LM Studio from [lmstudio.ai](https://lmstudio.ai/).
# + Start the application.
# + Select a model to load:
#
#     - From the developer tab, you can select a model from the top bar.
#     - Select a model, for example, any model from the Qwen3 class of models.
#     - Start the server with the control on the top-left labelled "Status: Stopped" or "Status: Running".
#
#
# <img src="./img/01_lmstudio.png" height="400">

# %% [markdown]
# With the setup above, we can point to the local server as indicated below. The API works similarly to OpenAI; however, the underlying model runs locally and was not necessarily produced by OpenAI.

# %%
from openai import OpenAI
client = OpenAI(base_url="http://127.0.0.1:1234/v1", api_key="not-needed")

response = client.responses.create(
    model = 'local-model',
    input = 'Hello world!',
)

# %%
from IPython.display import display, Markdown

display(Markdown(response.output_text))
# Out:
# Hello, world! 🌍
# It’s great to connect with you. Whether you have questions, need help, or just want to chat — I’m here to assist. What’s on your mind? 😊

# %%
response = client.responses.create(
    model = 'local-model',
    input = 'What type of inputs can I provide to you and what can you do with them?'
)

# %%
display(Markdown(response.output_text))
# Out:
# You can provide me with a wide variety of inputs, and I’ll do my best to assist you based on them. Here are the types of inputs I can handle:
#
# ---
#
# ### 📝 **Textual Inputs**
# You can type any text — questions, stories, instructions, essays, code, poems, or even random thoughts.
#
# **Examples:**
# - “Explain quantum computing in simple terms.”
# - “Write a fantasy story about a dragon who speaks only in riddles.”
# - “Fix this Python code: def add(a, b): return a + b”
#
# ---
#
# ### 🧠 **Questions & Research**
# Ask me anything — academic, technical, creative, or personal.
#
# **Examples:**
# - “What are the causes of climate change?”
# - “How do neural networks learn?”
# - “What’s the best way to start a podcast?”
#
# ---
#
# ### 💻 **Code & Programming**
# I can help with writing, debugging, or explaining code in any language (Python, JavaScript, C++, Java, etc.).
#
# **Examples:**
# - “Write a function to reverse a string in Python.”
# - “Debug this JavaScript error: ‘Cannot read property ‘x’ of undefined’.”
#
# ---
#
# ### 🎨 **Creative Writing & AI Tools**
# Generate stories, poems, emails, scripts, or even design prompts.
#
# **Examples:**
# - “Write a 300-word mystery story about a missing heirloom.”
# - “Generate a marketing email for a new coffee shop.”
#
# ---
#
# ### 📊 **Data & Analysis**
# You can paste data or ask me to analyze trends, create charts, or explain statistics.
#
# **Examples:**
# - “Given this dataset, what’s the correlation between age and income?”
# - “Explain how to create a bar chart in Excel.”
#
# ---
#
# ### 🧩 **Logic & Reasoning**
# Help with puzzles, logic problems, math, or philosophical questions.
#
# **Examples:**
# - “Solve this riddle: ‘I speak without a mouth and hear without ears. I have no body, but I come alive with wind.’”
# - “Prove that the sum of the first n natural numbers is n(n+1)/2.”
#
# ---
#
# ### 🧑‍🏫 **Learning & Teaching**
# I can explain concepts, summarize textbooks, or help you study.
#
# **Examples:**
# - “Explain the water cycle for a 5th grader.”
# - “Summarize ‘The Great Gatsby’ in 3 bullet points.”
#
# ---
#
# ### 🎧 **Multimedia & Tools**
# You can ask for help with tools, apps, or even describe a scene for a video.
#
# **Examples:**
# - “How do I make a TikTok video using Canva?”
# - “Describe a cinematic scene where a lone astronaut floats in space.”
#
# ---
#
# ### 🧑‍🤝‍🧑 **Personal & Emotional Support**
# While I’m not a therapist, I can offer support, advice, or just be a friendly listener.
#
# **Examples:**
# - “I’m feeling overwhelmed. What can I do?”
# - “How do I start a journal?”
#
# ---
#
# ### 🚀 **Advanced or Specialized Requests**
# You can ask me to generate code for a specific framework, design a UI, create a website structure, or even simulate a conversation.
#
# **Examples:**
# - “Design a user interface for a meditation app.”
# - “Simulate a 30-minute conversation between two people debating AI ethics.”
#
# ---
#
# ### ❗ Important Notes:
# - I don’t have real-time access to the internet (so I can’t fetch live data unless you provide it).
# - I don’t have personal knowledge or memories — everything I know is based on training data up to 2024.
# - I don’t have access to your private data or personal files unless you provide them in your message.
#
# ---
#
# ✅ **What I can do with your inputs:**
# - Answer your questions
# - Generate creative content
# - Write code or explain code
# - Help with math, logic, or puzzles
# - Summarize, expand, or rephrase text
# - Offer advice or support
# - Help you think through problems
#
# ---
#
# 💬 **Just type your input — and I’ll respond with the best I can!**
# Whether you want to learn, create, debug, or chat — I’m here to help.
#
# What would you like to ask or create? 🤖✨

# %% [markdown]
# ## Using an Image as Context
#
# There are several ways to interact with the client and use an image as context. They are discussed in the OpenAI platform [documentation](https://platform.openai.com/docs/guides/images-vision?format=base64-encoded#analyze-images). LMStudio inherits this behaviour as shown below.

# %%
import base64
# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")
# Path to your image
image_path = "./img/00_cat.jpg"

# Getting the Base64 string
base64_image = encode_image(image_path)


response = client.responses.create(
    model="gpt-4.1",
    input=[
        {
            "role": "user",
            "content": [
                { "type": "input_text", "text": "what's in this image?" },
                {
                    "type": "input_image",
                    "image_url": f"data:image/jpeg;base64,{base64_image}",
                },
            ],
        }
    ],
)

# %%
display(Markdown(response.output_text))
# Out:
# This image features a **striped tabby cat** sitting upright on a weathered, light-colored stone or concrete ledge. The cat is looking directly at the camera with bright green eyes and a calm, alert expression.
#
# Key details:
# - **The cat**: A brown and black striped tabby with a classic “M” marking on its forehead. Its ears are perked up, and it’s sitting in a poised, attentive posture.
# - **The setting**: The cat is outdoors, against a backdrop of bare, thin tree branches set against a pale, slightly overcast sky. This suggests it might be a cold season or a dry, winter-like day.
# - **The ledge**: The cat is perched on a rough, textured surface that appears to be a wall or fence, possibly in a garden or urban environment.
#
# The photo is taken with a shallow depth of field, keeping the cat sharply in focus while the background is softly blurred, drawing attention to the cat’s face and expression.
#
# Overall, it’s a peaceful, clear portrait of a domestic cat in a natural, outdoor setting.
